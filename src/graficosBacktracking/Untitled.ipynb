# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import numpy as np
import random
import math
import matplotlib as mpl

import io
import sys  

reload(sys)  
sys.setdefaultencoding('utf8')

#df = pd.read_csv('2.csv', ',')
df2 = pd.read_csv('geneticoBacktrack.csv')
print(df2)
#df.tiempo=df.tiempo/df.mov

#df.plot.scatter(x='mov', y='tiempo', color='Yellow', logx=True, label='N,M<11')
ax = df2.plot(x='generacion', y='maxFitness', color='Green',  label='Mejor',title='')
df2.plot(x='generacion', y='minFitness', color='Red', ax=ax, label='Peor')
df2.plot(x='generacion', y='fitnessPromedio', color='Blue', ax=ax, label='Promedio')
df2.plot(x='generacion', y='mediaDelFitness', color='Yellow', ax=ax, label='Media')

plt.ylabel('Fitness')
plt.xlabel('Generacion')
plt.show()

# %%
df2 = pd.read_csv('geneticoBacktrackTodosFitness.csv')
print(df2)
#df.tiempo=df.tiempo/df.mov

#df.plot.scatter(x='mov', y='tiempo', color='Yellow', logx=True, label='N,M<11')
ax = df2.plot(x='generacion', y='maxFitness', color='Green',  label='Mejor',title='')
df2.plot(x='generacion', y='minFitness', color='Red', ax=ax, label='Peor')
df2.plot(x='generacion', y='fitnessPromedio', color='Blue', ax=ax, label='Promedio')
df2.plot(x='generacion', y='mediaDelFitness', color='Yellow', ax=ax, label='Media')

plt.ylabel('Fitness')
plt.xlabel('Generacion')
